# %%
import pandas as pd
Input_data = pd.read_csv("/content/zomato.csv", encoding='ISO-8859-1')
Input_data
# Out:
#       Restaurant ID           Restaurant Name  ...  Rating text Votes
# 0           6317637          Le Petit Souffle  ...    Excellent   314
# 1           6304287          Izakaya Kikufuji  ...    Excellent   591
# 2           6300002    Heat - Edsa Shangri-La  ...    Very Good   270
# 3           6318506                      Ooma  ...    Excellent   365
# 4           6314302               Sambo Kojin  ...    Excellent   229
# ...             ...                       ...  ...          ...   ...
# 9546        5915730              NamlÛ± Gurme  ...    Very Good   788
# 9547        5908749             Ceviz AÛôacÛ±  ...    Very Good  1034
# 9548        5915807                     Huqqa  ...         Good   661
# 9549        5916112              Aôôk Kahve  ...    Very Good   901
# 9550        5927402  Walter's Coffee Roastery  ...    Very Good   591
#
# [9551 rows x 21 columns]

# %%
index = 0
Id = input("Enter the Restaurant ID:"+" ")
for _data in Input_data["Restaurant ID"]:
    #print(Id)
    if float(Id) == float(_data) :
          print("Zomato Restaurant information.......!!!")
          print("Restaurant Name:"+" "+ str(Input_data["Restaurant ID"][index]))
          print("Restaurant Name:"+" "+ Input_data["Restaurant Name"][index])
          print("Restaurant Located:"+" "+ Input_data["City"][index])
          print("Restaurant Address:"+" "+ (Input_data["Address"][index]).split(",")[])
          print("Restaurant Rating:"+" "+ str(Input_data["Aggregate rating"][index]))
          print("Restaurant color Rating:"+" "+ Input_data["Rating color"][index])
          print("Restaurant Review:"+" "+ Input_data["Rating text"][index]) 
          print("Average Cost for two person:"+" "+str(Input_data["Average Cost for two"][index])+"\n")
    index = index + 1
# Out:
# Enter the Restaurant ID: 6318506
# Swiggy Restaurant information.......!!!
# Restaurant Name: 6318506
# Restaurant Name: Ooma
# Restaurant Located: Mandaluyong City
# Restaurant Address: Third Floor, Mega Fashion Hall, SM Megamall, Ortigas, Mandaluyong City
# Restaurant Rating: 4.9
# Restaurant color Rating: Dark Green
# Restaurant Review: Excellent
# Average Cost for two person: 1500

# %%
)
